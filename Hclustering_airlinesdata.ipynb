# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %% [markdown]
# ### Read data set

# %%
airlines=pd.read_csv('EastWestAirlines.csv')
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
### Dropping ID# column
airline=airlines.drop(['ID#'],axis=1)
airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import normalize
airline_norm=pd.DataFrame(normalize(airline),columns=airline.columns)
airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### DENDROGRAM

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch  
z = linkage(airline_norm, method="average",metric="euclidean")
plt.figure(figsize=(10, 7))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(
z,
)
plt.show()

# %% [markdown]
# ### Average linkage

# %%
from sklearn.cluster import AgglomerativeClustering 
import warnings 
warnings.filterwarnings('ignore')
h_complete = AgglomerativeClustering(n_clusters=6, linkage='average',affinity = "euclidean").fit(data) 

cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
airline['clust']=cluster_labels 
airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ##### mean of clusters

# %%
airlines.iloc[:,1:].groupby(airline.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0      261870.333333  551.333333   4.600000   1.000000   1.000000
# 1       59807.839555   87.602462   1.705322   1.013900   1.008737
# 2       95465.793246  238.429359   2.643005   1.007581   1.002068
# 3      223573.500000  250.000000   1.000000   1.000000   1.000000
# 4       73699.142857    0.000000   4.285714   1.000000   4.428571
# 5       53934.500000  166.666667   1.000000   3.000000   1.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clust
# 0      138424.200000    41.266667        5917.600000        17.133333
# 1       10227.689039     9.142971         226.292295         0.652502
# 2       27288.223294    15.327360         775.337698         2.366644
# 3       49057.500000    72.000000       21845.000000        53.000000
# 4      124732.428571    30.857143         357.142857         1.000000
# ...

# %% [markdown]
# ### Cluster 0

# %%
data = airline[(airline.clust==0)]
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 126    602064           0          5          1          1       194753
# 151    930410           0          5          1          1       211284
# 190    123516           0          5          1          1       240544
# 380    377252           0          5          1          1       230629
# 437    353678           0          4          1          1       141230
# 534    267404           0          5          1          1       263685
# 2015    53232         888          4          1          1        80696
# 2413   190674        4704          5          1          1       104159
# 2709   405499        1000          4          1          1        72318
# 2775   187999           0          4          1          1        52429
# 3249    51680           0          4          1          1        54926
# 3429   133351           0          5          1          1        84215
# ...

# %% [markdown]
# ### Cluster 1

# %%
data = airline[(airline.clust==1)]
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 5       16420           0          1          1          1            0
# ...       ...         ...        ...        ...        ...          ...
# 3991    39142           0          3          1          1        14981
# 3992    11181           0          1          1          1          929
# 3993     3974           0          1          1          1          365
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Cluster 2

# %%
data = airline[(airline.clust==2)]
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4       97752           0          4          1          1        43300
# 7       20856           0          1          1          1         5250
# 8      443003           0          3          2          1         1753
# 9      104860           0          3          1          1        28426
# 11      96522           0          5          1          1        61105
# ...       ...         ...        ...        ...        ...          ...
# 3987    11933           0          1          1          1          249
# 3989     2622           0          1          1          1         1625
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### Cluster 3

# %%
data = airline[(airline.clust==3)]
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3235   287033           0          1          1          1        26161
# 3583   160114         500          1          1          1        71954
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3235           58              12873               53               2272
# 3583           86              30817               53               1373
#
#       Award?  clust
# 3235       1      3
# 3583       1      3

# %% [markdown]
# ### Cluster 4

# %%
data = airline[(airline.clust==4)]
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 384     28193           0          5          1          4       103456
# 850     25629           0          4          1          5       107308
# 904     15835           0          2          1          5       112171
# 1878   128302           0          5          1          4       132263
# 1917    82981           0          5          1          3       105325
# 1946   126873           0          4          1          5        95598
# 2364   108081           0          5          1          5       217006
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 384            32                  0                0               6980
# 850            36                600                2               5966
# 904            16                  0                0               5825
# 1878           32                400                2               4103
# ...

# %% [markdown]
# ### Cluster 5

# %%
data = airline[(airline.clust==5)]
data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 198      8669           0          1          3          1        11397
# 940     44824           0          1          3          1        21107
# 2047     4148           0          1          3          1        13504
# 2166   100634           0          1          3          1        69669
# 2978    22805           0          1          3          1        26334
# 2999   142527        1000          1          3          1        24091
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 198            16                  0                0               7486
# 940            19               2000                4               5916
# 2047           18                  0                0               4607
# 2166           28               1540               12               4193
# 2978           27               1800                6               3294
# ...

# %%
### trying with single linkage
from sklearn.cluster import AgglomerativeClustering 
import warnings 
warnings.filterwarnings('ignore')
h_complete = AgglomerativeClustering(n_clusters=6, linkage='single',affinity = "euclidean").fit(data) 

cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
airline['clust']=cluster_labels 
airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...
